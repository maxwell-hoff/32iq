# %%
import pandas as pd
import subprocess
import os
pd.set_option("max_colwidth", None)
pd.set_option('display.max_columns', None)

# %%
cwd = os.getcwd()

# %%
folder_version = 'transformed_v1/transformed_v1'

# %%
col_transforms = ['','_horizontal','_horizontal_rotation_down', '_horizontal_rotation_up','_rotation_down','_rotation_up']

# %%
col_categories = ['radiographs','gaze_map_quantized','mask','teeth_mask','maxillomandibular']

# %%
# # make sure all files have similar file format (all upper case)
# for col_transform in col_transforms:
#     for col_category in col_categories:
#         subprocess.run(['mkdir',f'/Users/maxhoff/Downloads/transformed_v2/{col_category+col_transform}'])
#         for file in os.listdir(f'/Users/maxhoff/Downloads/transformed_v1/{col_category+col_transform}/'):
#             subprocess.run(["cp", 
#                             f"/Users/maxhoff/Downloads/transformed_v1/{col_category+col_transform}/{file}", 
#                             f"/Users/maxhoff/Downloads/transformed_v2/{col_category+col_transform}/{file.lower()}"])

# %%
# read in image labels
df = pd.read_csv("/Users/maxhoff/Documents/MIDS/w210/image_labels.csv")

# %%
# Find which images are in all folders/missing
agg_file_list = pd.DataFrame(os.listdir(f'/Users/maxhoff/Downloads/transformed_v2/radiographs/'),
                             columns=['image_ID']) # create initial image ID list
agg_file_list['image_ID'] = agg_file_list['image_ID'].str.lower() # capitalize all image IDs - for standarization purposes
for col_category in col_categories:
    for col_transform in col_transforms:
        # create a list of image_ID's for each folder
        category_list = pd.DataFrame(os.listdir(f'/Users/maxhoff/Downloads/transformed_v2/{col_category+col_transform}/'),
                                     columns=['image_ID'])
        # create indicator column for each folder
        category_list[col_category+col_transform] = 1
        # standardize image IDs to have only lower cases - currently not standard
        category_list['image_ID'] = category_list['image_ID'].str.lower()
        agg_file_list = agg_file_list.merge(category_list, how='outer', on='image_ID')

# %%
# count number of times an image ID appears across all folders
agg_file_list['folder_count'] = 0
for row in range(0, len(agg_file_list)-1):
    agg_file_list.iloc[row,len(agg_file_list.columns)-1] = agg_file_list.iloc[row,1:].sum()

# %%
images_within_all_folders = list(agg_file_list.loc[agg_file_list['folder_count'] == 30,'image_ID'])

# %%
df['image_ID'] = df['image_ID'].str.lower()

# %%
df = df.loc[df['image_ID'].isin(images_within_all_folders),:]

# %%
# read in exclusion list and remove
exclude_images = pd.read_csv(f'{cwd}/exclude_images.csv', header=None)
consider_exclude_images = pd.read_csv(f'{cwd}/consider_exclude_images.csv', header=None)
exclude_imgs = []
for img in list(exclude_images[0]):
    exclude_imgs.append(str(img)+'.JPG')
df = df[~df['image_ID'].isin(exclude_imgs)]
consider_exclude_imgs = []
for img in list(consider_exclude_images[0]):
    consider_exclude_imgs.append(str(img)+'.JPG')
df = df[~df['image_ID'].isin(consider_exclude_imgs)]

# %%
# keep only cavity cases - since those are more clear cut
df = df.loc[df['label'].isin(['periapical','none']),:]

# %%
# one hot encode labels
df.loc[df['label']!='none','label'] = 1
df.loc[df['label']=='none','label'] = 0

# %%
agg_df = pd.DataFrame()
for col_transform in col_transforms:
    # create df for each type of column - to concat at end
    globals()[f"df_{col_transform}"] = df.copy()
    for image_id in globals()[f"df_{col_transform}"]['image_ID']:
        for col_category in col_categories:
            # add image link for each category
            globals()[f"df_{col_transform}"].loc[globals()[f"df_{col_transform}"]['image_ID'] == image_id,f'{col_category}_image_link'] = f'https://w210-32iq.s3.amazonaws.com/{col_category+col_transform}/{image_id}' #f'https://storage.cloud.google.com/w210-32iq/{col_category+col_transform}/{image_id}'
    # create a new unique image id - since image id will be duplicated across categories
    globals()[f"df_{col_transform}"]['image_ID_new'] = globals()[f"df_{col_transform}"]['image_ID'].str.upper() + col_transform
    # create category field
    globals()[f"df_{col_transform}"]['category'] = col_transform
    # filter to only images that are within every folder
    globals()[f"df_{col_transform}"] = globals()[f"df_{col_transform}"].loc[globals()[f"df_{col_transform}"]['image_ID'].isin(images_within_all_folders),:]
    # concat dfs
    agg_df = pd.concat([agg_df, globals()[f"df_{col_transform}"]])
agg_df = agg_df.reset_index()
agg_df.drop(columns='index',inplace=True)

# %%
agg_df['image_links'] = ''
for row in range(0,len(agg_df)):
    agg_df.at[row,'image_links'] = [agg_df.loc[row,f'{col}_image_link'] for col in col_categories]

# %%
agg_df_dis = agg_df[agg_df['label'] == 1]
agg_df_no_dis = agg_df[agg_df['label'] == 0]

# %%
agg_df_no_dis = agg_df_no_dis.loc[agg_df_no_dis.index < len(agg_df_no_dis),:]

# %%
agg_df_balanced = pd.concat([agg_df_dis, agg_df_no_dis])

# %%
# output_df = agg_df[['label','radiographs_image_link','gaze_map_quantized_image_link','mask_image_link','teeth_mask_image_link','maxillomandibular_image_link']]
output_df = agg_df_balanced[['label','radiographs_image_link','gaze_map_quantized_image_link','mask_image_link','teeth_mask_image_link','maxillomandibular_image_link']]

# %%
# output_df.to_csv('output.csv',index=False)
output_df.to_csv(f'{cwd}/outputs/aws-output-balanced-liberal-clean.csv',index=False)

# %% [markdown]
# Inspect individual images

# %%
len(output_df)
# Out:
# 4272

# %%
agg_df[agg_df['image_ID'] == '42.JPG'][['radiographs_image_link','mask_image_link']]
# Out:
# Empty DataFrame
# Columns: [radiographs_image_link, mask_image_link]
# Index: []

# %%
output_df.sort_values(by='radiographs_image_link').head(50)
# Out:
#     label                                   radiographs_image_link  \
# 112     1     https://w210-32iq.s3.amazonaws.com/radiographs/1.jpg
# 865     0  https://w210-32iq.s3.amazonaws.com/radiographs/1000.jpg
# 876     1  https://w210-32iq.s3.amazonaws.com/radiographs/1001.jpg
# 852     1  https://w210-32iq.s3.amazonaws.com/radiographs/1002.jpg
# 841     1  https://w210-32iq.s3.amazonaws.com/radiographs/1004.jpg
# 845     0  https://w210-32iq.s3.amazonaws.com/radiographs/1007.jpg
# 870     1  https://w210-32iq.s3.amazonaws.com/radiographs/1009.jpg
# 869     1  https://w210-32iq.s3.amazonaws.com/radiographs/1009.jpg
# 412     0   https://w210-32iq.s3.amazonaws.com/radiographs/101.jpg
# 847     1  https://w210-32iq.s3.amazonaws.com/radiographs/1010.jpg
# 859     1  https://w210-32iq.s3.amazonaws.com/radiographs/1011.jpg
# 849     0  https://w210-32iq.s3.amazonaws.com/radiographs/1013.jpg
# 861     0  https://w210-32iq.s3.amazonaws.com/radiographs/1014.jpg
# 873     1  https://w210-32iq.s3.amazonaws.com/radiographs/1015.jpg
# 850     1  https://w210-32iq.s3.amazonaws.com/radiographs/1016.jpg
# 863     0  https://w210-32iq.s3.amazonaws.com/radiographs/1017.jpg
# 874     0  https://w210-32iq.s3.amazonaws.com/radiographs/1018.jpg
# 702     0   https://w210-32iq.s3.amazonaws.com/radiographs/102.jpg
# 864     0  https://w210-32iq.s3.amazonaws.com/radiographs/1020.jpg
# 875     0  https://w210-32iq.s3.amazonaws.com/radiographs/1021.jpg
# 840     0  https://w210-32iq.s3.amazonaws.com/radiographs/1024.jpg
# 853     0  https://w210-32iq.s3.amazonaws.com/radiographs/1025.jpg
# 842     0  https://w210-32iq.s3.amazonaws.com/radiographs/1027.jpg
# 854     0  https://w210-32iq.s3.amazonaws.com/radiographs/1028.jpg
# 843     0  https://w210-32iq.s3.amazonaws.com/radiographs/1030.jpg
# 855     0  https://w210-32iq.s3.amazonaws.com/radiographs/1031.jpg
# 866     0  https://w210-32iq.s3.amazonaws.com/radiographs/1032.jpg
# 856     1  https://w210-32iq.s3.amazonaws.com/radiographs/1034.jpg
# 867     0  https://w210-32iq.s3.amazonaws.com/radiographs/1035.jpg
# 844     1  https://w210-32iq.s3.amazonaws.com/radiographs/1036.jpg
# 857     1  https://w210-32iq.s3.amazonaws.com/radiographs/1037.jpg
# 868     0  https://w210-32iq.s3.amazonaws.com/radiographs/1038.jpg
# 846     0  https://w210-32iq.s3.amazonaws.com/radiographs/1039.jpg
# 432     0   https://w210-32iq.s3.amazonaws.com/radiographs/104.jpg
# 858     0  https://w210-32iq.s3.amazonaws.com/radiographs/1040.jpg
# 871     0  https://w210-32iq.s3.amazonaws.com/radiographs/1041.jpg
# 848     0  https://w210-32iq.s3.amazonaws.com/radiographs/1042.jpg
# 860     0  https://w210-32iq.s3.amazonaws.com/radiographs/1043.jpg
# 872     0  https://w210-32iq.s3.amazonaws.com/radiographs/1044.jpg
# 862     0  https://w210-32iq.s3.amazonaws.com/radiographs/1046.jpg
# 730     1   https://w210-32iq.s3.amazonaws.com/radiographs/105.jpg
# 851     0  https://w210-32iq.s3.amazonaws.com/radiographs/1051.jpg
# 197     1   https://w210-32iq.s3.amazonaws.com/radiographs/106.jpg
# 464     1   https://w210-32iq.s3.amazonaws.com/radiographs/107.jpg
# 762     0   https://w210-32iq.s3.amazonaws.com/radiographs/108.jpg
# 223     1   https://w210-32iq.s3.amazonaws.com/radiographs/109.jpg
# 458     0    https://w210-32iq.s3.amazonaws.com/radiographs/11.jpg
# 490     0   https://w210-32iq.s3.amazonaws.com/radiographs/110.jpg
# 790     0   https://w210-32iq.s3.amazonaws.com/radiographs/111.jpg
# 515     0   https://w210-32iq.s3.amazonaws.com/radiographs/113.jpg
#
#                                       gaze_map_quantized_image_link  \
# 112     https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1.jpg
# 865  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1000.jpg
# 876  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1001.jpg
# 852  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1002.jpg
# 841  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1004.jpg
# 845  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1007.jpg
# 870  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1009.jpg
# 869  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1009.jpg
# 412   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/101.jpg
# 847  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1010.jpg
# 859  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1011.jpg
# 849  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1013.jpg
# 861  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1014.jpg
# 873  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1015.jpg
# 850  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1016.jpg
# 863  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1017.jpg
# 874  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1018.jpg
# 702   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/102.jpg
# 864  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1020.jpg
# 875  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1021.jpg
# 840  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1024.jpg
# 853  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1025.jpg
# 842  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1027.jpg
# 854  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1028.jpg
# 843  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1030.jpg
# 855  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1031.jpg
# 866  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1032.jpg
# 856  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1034.jpg
# 867  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1035.jpg
# 844  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1036.jpg
# 857  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1037.jpg
# 868  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1038.jpg
# 846  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1039.jpg
# 432   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/104.jpg
# 858  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1040.jpg
# 871  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1041.jpg
# 848  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1042.jpg
# 860  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1043.jpg
# 872  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1044.jpg
# 862  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1046.jpg
# 730   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/105.jpg
# 851  https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/1051.jpg
# 197   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/106.jpg
# 464   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/107.jpg
# 762   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/108.jpg
# 223   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/109.jpg
# 458    https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/11.jpg
# 490   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/110.jpg
# 790   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/111.jpg
# 515   https://w210-32iq.s3.amazonaws.com/gaze_map_quantized/113.jpg
#
#                                       mask_image_link  \
# 112     https://w210-32iq.s3.amazonaws.com/mask/1.jpg
# 865  https://w210-32iq.s3.amazonaws.com/mask/1000.jpg
# 876  https://w210-32iq.s3.amazonaws.com/mask/1001.jpg
# 852  https://w210-32iq.s3.amazonaws.com/mask/1002.jpg
# 841  https://w210-32iq.s3.amazonaws.com/mask/1004.jpg
# 845  https://w210-32iq.s3.amazonaws.com/mask/1007.jpg
# 870  https://w210-32iq.s3.amazonaws.com/mask/1009.jpg
# 869  https://w210-32iq.s3.amazonaws.com/mask/1009.jpg
# 412   https://w210-32iq.s3.amazonaws.com/mask/101.jpg
# 847  https://w210-32iq.s3.amazonaws.com/mask/1010.jpg
# 859  https://w210-32iq.s3.amazonaws.com/mask/1011.jpg
# 849  https://w210-32iq.s3.amazonaws.com/mask/1013.jpg
# 861  https://w210-32iq.s3.amazonaws.com/mask/1014.jpg
# 873  https://w210-32iq.s3.amazonaws.com/mask/1015.jpg
# 850  https://w210-32iq.s3.amazonaws.com/mask/1016.jpg
# 863  https://w210-32iq.s3.amazonaws.com/mask/1017.jpg
# 874  https://w210-32iq.s3.amazonaws.com/mask/1018.jpg
# 702   https://w210-32iq.s3.amazonaws.com/mask/102.jpg
# 864  https://w210-32iq.s3.amazonaws.com/mask/1020.jpg
# 875  https://w210-32iq.s3.amazonaws.com/mask/1021.jpg
# 840  https://w210-32iq.s3.amazonaws.com/mask/1024.jpg
# 853  https://w210-32iq.s3.amazonaws.com/mask/1025.jpg
# 842  https://w210-32iq.s3.amazonaws.com/mask/1027.jpg
# 854  https://w210-32iq.s3.amazonaws.com/mask/1028.jpg
# 843  https://w210-32iq.s3.amazonaws.com/mask/1030.jpg
# 855  https://w210-32iq.s3.amazonaws.com/mask/1031.jpg
# 866  https://w210-32iq.s3.amazonaws.com/mask/1032.jpg
# 856  https://w210-32iq.s3.amazonaws.com/mask/1034.jpg
# 867  https://w210-32iq.s3.amazonaws.com/mask/1035.jpg
# 844  https://w210-32iq.s3.amazonaws.com/mask/1036.jpg
# 857  https://w210-32iq.s3.amazonaws.com/mask/1037.jpg
# 868  https://w210-32iq.s3.amazonaws.com/mask/1038.jpg
# 846  https://w210-32iq.s3.amazonaws.com/mask/1039.jpg
# 432   https://w210-32iq.s3.amazonaws.com/mask/104.jpg
# 858  https://w210-32iq.s3.amazonaws.com/mask/1040.jpg
# 871  https://w210-32iq.s3.amazonaws.com/mask/1041.jpg
# 848  https://w210-32iq.s3.amazonaws.com/mask/1042.jpg
# 860  https://w210-32iq.s3.amazonaws.com/mask/1043.jpg
# 872  https://w210-32iq.s3.amazonaws.com/mask/1044.jpg
# 862  https://w210-32iq.s3.amazonaws.com/mask/1046.jpg
# 730   https://w210-32iq.s3.amazonaws.com/mask/105.jpg
# 851  https://w210-32iq.s3.amazonaws.com/mask/1051.jpg
# 197   https://w210-32iq.s3.amazonaws.com/mask/106.jpg
# 464   https://w210-32iq.s3.amazonaws.com/mask/107.jpg
# 762   https://w210-32iq.s3.amazonaws.com/mask/108.jpg
# 223   https://w210-32iq.s3.amazonaws.com/mask/109.jpg
# 458    https://w210-32iq.s3.amazonaws.com/mask/11.jpg
# 490   https://w210-32iq.s3.amazonaws.com/mask/110.jpg
# 790   https://w210-32iq.s3.amazonaws.com/mask/111.jpg
# 515   https://w210-32iq.s3.amazonaws.com/mask/113.jpg
#
#                                       teeth_mask_image_link  \
# 112     https://w210-32iq.s3.amazonaws.com/teeth_mask/1.jpg
# 865  https://w210-32iq.s3.amazonaws.com/teeth_mask/1000.jpg
# 876  https://w210-32iq.s3.amazonaws.com/teeth_mask/1001.jpg
# 852  https://w210-32iq.s3.amazonaws.com/teeth_mask/1002.jpg
# 841  https://w210-32iq.s3.amazonaws.com/teeth_mask/1004.jpg
# 845  https://w210-32iq.s3.amazonaws.com/teeth_mask/1007.jpg
# 870  https://w210-32iq.s3.amazonaws.com/teeth_mask/1009.jpg
# 869  https://w210-32iq.s3.amazonaws.com/teeth_mask/1009.jpg
# 412   https://w210-32iq.s3.amazonaws.com/teeth_mask/101.jpg
# 847  https://w210-32iq.s3.amazonaws.com/teeth_mask/1010.jpg
# 859  https://w210-32iq.s3.amazonaws.com/teeth_mask/1011.jpg
# 849  https://w210-32iq.s3.amazonaws.com/teeth_mask/1013.jpg
# 861  https://w210-32iq.s3.amazonaws.com/teeth_mask/1014.jpg
# 873  https://w210-32iq.s3.amazonaws.com/teeth_mask/1015.jpg
# 850  https://w210-32iq.s3.amazonaws.com/teeth_mask/1016.jpg
# 863  https://w210-32iq.s3.amazonaws.com/teeth_mask/1017.jpg
# 874  https://w210-32iq.s3.amazonaws.com/teeth_mask/1018.jpg
# 702   https://w210-32iq.s3.amazonaws.com/teeth_mask/102.jpg
# 864  https://w210-32iq.s3.amazonaws.com/teeth_mask/1020.jpg
# 875  https://w210-32iq.s3.amazonaws.com/teeth_mask/1021.jpg
# 840  https://w210-32iq.s3.amazonaws.com/teeth_mask/1024.jpg
# 853  https://w210-32iq.s3.amazonaws.com/teeth_mask/1025.jpg
# 842  https://w210-32iq.s3.amazonaws.com/teeth_mask/1027.jpg
# 854  https://w210-32iq.s3.amazonaws.com/teeth_mask/1028.jpg
# 843  https://w210-32iq.s3.amazonaws.com/teeth_mask/1030.jpg
# 855  https://w210-32iq.s3.amazonaws.com/teeth_mask/1031.jpg
# 866  https://w210-32iq.s3.amazonaws.com/teeth_mask/1032.jpg
# 856  https://w210-32iq.s3.amazonaws.com/teeth_mask/1034.jpg
# 867  https://w210-32iq.s3.amazonaws.com/teeth_mask/1035.jpg
# 844  https://w210-32iq.s3.amazonaws.com/teeth_mask/1036.jpg
# 857  https://w210-32iq.s3.amazonaws.com/teeth_mask/1037.jpg
# 868  https://w210-32iq.s3.amazonaws.com/teeth_mask/1038.jpg
# 846  https://w210-32iq.s3.amazonaws.com/teeth_mask/1039.jpg
# 432   https://w210-32iq.s3.amazonaws.com/teeth_mask/104.jpg
# 858  https://w210-32iq.s3.amazonaws.com/teeth_mask/1040.jpg
# 871  https://w210-32iq.s3.amazonaws.com/teeth_mask/1041.jpg
# 848  https://w210-32iq.s3.amazonaws.com/teeth_mask/1042.jpg
# 860  https://w210-32iq.s3.amazonaws.com/teeth_mask/1043.jpg
# 872  https://w210-32iq.s3.amazonaws.com/teeth_mask/1044.jpg
# 862  https://w210-32iq.s3.amazonaws.com/teeth_mask/1046.jpg
# 730   https://w210-32iq.s3.amazonaws.com/teeth_mask/105.jpg
# 851  https://w210-32iq.s3.amazonaws.com/teeth_mask/1051.jpg
# 197   https://w210-32iq.s3.amazonaws.com/teeth_mask/106.jpg
# 464   https://w210-32iq.s3.amazonaws.com/teeth_mask/107.jpg
# 762   https://w210-32iq.s3.amazonaws.com/teeth_mask/108.jpg
# 223   https://w210-32iq.s3.amazonaws.com/teeth_mask/109.jpg
# 458    https://w210-32iq.s3.amazonaws.com/teeth_mask/11.jpg
# 490   https://w210-32iq.s3.amazonaws.com/teeth_mask/110.jpg
# 790   https://w210-32iq.s3.amazonaws.com/teeth_mask/111.jpg
# 515   https://w210-32iq.s3.amazonaws.com/teeth_mask/113.jpg
#
#                                       maxillomandibular_image_link
# 112     https://w210-32iq.s3.amazonaws.com/maxillomandibular/1.jpg
# 865  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1000.jpg
# 876  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1001.jpg
# 852  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1002.jpg
# 841  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1004.jpg
# 845  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1007.jpg
# 870  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1009.jpg
# 869  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1009.jpg
# 412   https://w210-32iq.s3.amazonaws.com/maxillomandibular/101.jpg
# 847  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1010.jpg
# 859  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1011.jpg
# 849  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1013.jpg
# 861  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1014.jpg
# 873  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1015.jpg
# 850  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1016.jpg
# 863  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1017.jpg
# 874  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1018.jpg
# 702   https://w210-32iq.s3.amazonaws.com/maxillomandibular/102.jpg
# 864  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1020.jpg
# 875  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1021.jpg
# 840  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1024.jpg
# 853  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1025.jpg
# 842  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1027.jpg
# 854  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1028.jpg
# 843  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1030.jpg
# 855  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1031.jpg
# 866  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1032.jpg
# 856  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1034.jpg
# 867  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1035.jpg
# 844  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1036.jpg
# 857  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1037.jpg
# 868  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1038.jpg
# 846  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1039.jpg
# 432   https://w210-32iq.s3.amazonaws.com/maxillomandibular/104.jpg
# 858  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1040.jpg
# 871  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1041.jpg
# 848  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1042.jpg
# 860  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1043.jpg
# 872  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1044.jpg
# 862  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1046.jpg
# 730   https://w210-32iq.s3.amazonaws.com/maxillomandibular/105.jpg
# 851  https://w210-32iq.s3.amazonaws.com/maxillomandibular/1051.jpg
# 197   https://w210-32iq.s3.amazonaws.com/maxillomandibular/106.jpg
# 464   https://w210-32iq.s3.amazonaws.com/maxillomandibular/107.jpg
# 762   https://w210-32iq.s3.amazonaws.com/maxillomandibular/108.jpg
# 223   https://w210-32iq.s3.amazonaws.com/maxillomandibular/109.jpg
# 458    https://w210-32iq.s3.amazonaws.com/maxillomandibular/11.jpg
# 490   https://w210-32iq.s3.amazonaws.com/maxillomandibular/110.jpg
# 790   https://w210-32iq.s3.amazonaws.com/maxillomandibular/111.jpg
# 515   https://w210-32iq.s3.amazonaws.com/maxillomandibular/113.jpg
